# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import write
from scipy.fft import fft, fftfreq

# %%
SAMPLE_RATE = 44100
DURATION = 5

def generate_sine_wave(freq, sample_rate, duration):
    x = np.linspace(0, duration, sample_rate*duration, endpoint=False)
    frequencies = x * freq
    y = np.sin((2 * np.pi) * frequencies)
    return x, y

x,y = generate_sine_wave(2, SAMPLE_RATE, DURATION)

plt.plot(x,y)
plt.show()
# Out:
# [0.00000000e+00 2.26757370e-05 4.53514739e-05 ... 4.99993197e+00
#  4.99995465e+00 4.99997732e+00]

# %%
_, nice_tone = generate_sine_wave(400, SAMPLE_RATE, DURATION)
_, noise_tone = generate_sine_wave(4000, SAMPLE_RATE, DURATION)
noise_tone =  noise_tone * 0.3

mixed_tone = nice_tone + noise_tone

normalized_tone = np.int16((mixed_tone / mixed_tone.max()) * 32767)

plt.plot(normalized_tone[:1000])
plt.show()

write("noise.wav", SAMPLE_RATE, normalized_tone)
# Out:
# [0.00000000e+00 2.26757370e-05 4.53514739e-05 ... 4.99993197e+00
#  4.99995465e+00 4.99997732e+00]
# [0.00000000e+00 2.26757370e-05 4.53514739e-05 ... 4.99993197e+00
#  4.99995465e+00 4.99997732e+00]

# %%
N = SAMPLE_RATE * DURATION

yf = fft(normalized_tone)
xf = fftfreq(N, 1/SAMPLE_RATE)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(stop_words='english')
print(vectorizer.get_stop_words())
# Out:
# frozenset({'because', 'thereby', 'much', 'whether', 'yourselves', 'then', 'fifty', 'therein', 'wherever', 'my', 'two', 'well', 'now', 'he', 'mine', 'fill', 'mill', 'full', 'seemed', 'anywhere', 'up', 'both', 'themselves', 'own', 'meanwhile', 'call', 'this', 'than', 'ourselves', 'twenty', 'give', 'i', 'keep', 'somewhere', 'whereupon', 'sincere', 'his', 'there', 'herself', 'at', 'still', 'always', 'afterwards', 'hereafter', 'toward', 'and', 'thereafter', 'am', 'for', 'what', 'due', 'as', 'had', 'perhaps', 'beyond', 'inc', 'thin', 'ten', 'eight', 'a', 'through', 'while', 'can', 'has', 'put', 'everywhere', 'system', 'with', 'few', 'its', 'became', 'empty', 'anyhow', 'part', 'again', 'four', 'next', 'show', 'too', 'namely', 'onto', 'against', 'nor', 'whereafter', 'same', 'thru', 'once', 'to', 'her', 'serious', 'hasnt', 'neither', 'whenever', 'beforehand', 'therefore', 'whereby', 'those', 'among', 'below', 'sometime', 'done', 'will', 'amount', 'an', 'being', 'bottom', 'nobody', 'via', 'under', 'even', 'hers', 'almost', 'moreover', 'one', 'all', 'whoever', 'each', 'last', 'throughout', 'herein', 'per', 'so', 'how', 'fifteen', 'become', 'not', 'in', 'third', 'someone', 'of', 'nevertheless', 'former', 'enough', 'mostly', 'further', 'every', 'might', 'should', 'between', 'cant', 'ltd', 'the', 'latterly', 'been', 'out', 'within', 'your', 'was', 'becoming', 're', 'whereas', 'where', 'no', 'have', 'more', 'con', 'though', 'around', 'first', 'until', 'thence', 'you', 'either', 'noone', 'everyone', 'name', 'de', 'before', 'most', 'sometimes', 'across', 'me', 'see', 'find', 'co', 'except', 'they', 'thus', 'other', 'take', 'everything', 'hereby', 'himself', 'if', 'into', 'twelve', 'she', 'their', 'three', 'along', 'thick', 'when', 'elsewhere', 'ours', 'us', 'whole', 'down', 'already', 'from', 'are', 'during', 'do', 'ever', 'anyway', 'seeming', 'top', 'upon', 'above', 'although', 'forty', 'behind', 'also', 'eleven', 'only', 'whatever', 'very', 'amongst', 'hence', 'together', 'yours', 'be', 'made', 'anything', 'these', 'myself', 'our', 'front', 'rather', 'beside', 'nine', 'seems', 'about', 'cry', 'five', 'couldnt', 'un', 'by', 'hereupon', 'less', 'many', 'etc', 'him', 'alone', 'after', 'formerly', 'something', 'nothing', 'is', 'sixty', 'were', 'whom', 'some', 'back', 'it', 'seem', 'but', 'six', 'would', 'another', 'eg', 'off', 'besides', 'here', 'somehow', 'that', 'often', 'nowhere', 'go', 'others', 'cannot', 'however', 'without', 'on', 'wherein', 'detail', 'least', 'must', 'yet', 'whence', 'who', 'whose', 'latter', 'such', 'since', 'over', 'otherwise', 'never', 'amoungst', 'why', 'get', 'found', 'may', 'fire', 'else', 'could', 'thereupon', 'side', 'hundred', 'anyone', 'bill', 'or', 'please', 'ie', 'describe', 'which', 'yourself', 'interest', 'any', 'move', 'we', 'them', 'none', 'indeed', 'becomes', 'itself', 'towards', 'whither', 'several'})
